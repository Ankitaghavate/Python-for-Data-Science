# %%
import plotly as px
import pandas as pd
import numpy as np
from plotly import __version__

# %%
print(__version__)
# Out:
# 5.24.1

# %%
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# data
df=pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
df.head()
# Out:
#           A         B         C         D
# 0 -0.013773 -0.605755 -0.070125  0.472537
# 1 -0.706289 -0.176269 -2.181335 -0.357294
# 2  0.211925  0.566427  0.731140 -0.077691
# 3  1.144341 -0.296976 -0.561174 -0.326182
# 4 -0.506165 -0.037613 -1.452913  1.795502

# %%
df2=pd.DataFrame(np.random.randn(200,5),columns='X Y Z M N'.split())
df2
# Out:
#             X         Y         Z         M         N
# 0   -0.392949  0.607979 -1.114252 -0.138618  0.587463
# 1   -0.005956  0.710445  0.352161 -0.729288 -0.342864
# 2    0.169067  1.393279 -0.228284  0.324633  1.951089
# 3   -0.687547  1.408005  0.478968  0.299464  0.937163
# 4   -0.477991  1.763278  1.984528  1.114677  0.412523
# ..        ...       ...       ...       ...       ...
# 195  1.658355  1.049583  0.354863  0.358392 -0.449273
# 196 -1.676324 -0.080616 -0.016906  0.207147  2.509841
# 197 -0.214973 -0.589469 -0.025537  1.338169  0.272511
# 198  0.840545  0.583650 -1.353738 -0.018290 -1.070278
# 199 -0.154247 -0.484586  2.096560 -1.072704  0.748551
#
# [200 rows x 5 columns]

# %%
pd.DataFrame({'category':['A','B','C'], 'values': [32,45,67]})
# Out:
#   category  values
# 0        A      32
# 1        B      45
# 2        C      67

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.iplot()

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=20)

# %%
df.iplot(kind='scatter',x='B',y='C',mode='markers',size=10,color='red')

# %%
df.iplot(kind='bar',x='A',y='B')

# %%
df.sum().iplot(kind='bar')

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df3=pd.DataFrame({'X':[1,2,3,4],'y':[10,20,30,40],'z':[50,60,70,80]})
df3
# Out:
#    X   y   z
# 0  1  10  50
# 1  2  20  60
# 2  3  30  70
# 3  4  40  80

# %%
df3.iplot(kind='surface')

# %%
df['A'].iplot(kind='hist',bins=24)

# %%
#df[['A','B']].iplot(kind='spread')

# %%
df.iplot(kind='bubble',x='A',y='B',size='C',color='red')

# %%
df.scatter_matrix()
